# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_column", None)

# %%
sns.set(style="whitegrid", palette="pastel", font_scale=1)
plt.rcParams["figure.figsize"] = (10,6)

# %%
df = pd.read_excel("Bank_updated.xlsx")

# %%
df.head()
# Out:
#   Client_ID Status_of_existing_checking_account  Duration_in_month  \
# 0    C00001                    50,000 – 499,999                  9
# 1    C00002                      5,000 – 49,999                 53
# 2    C00003                             < 5,000                  7
# 3    C00004                    50,000 – 499,999                 25
# 4    C00005                             < 5,000                 50
#
#                                       Credit_history        Purpose  \
# 0       no credits taken/ all credits paid back duly   Housing Loan
# 1  critical account/other credits existing (not a...    Credit Card
# 2       no credits taken/ all credits paid back duly  Personal Loan
# 3       no credits taken/ all credits paid back duly    Credit Card
# 4                    delay in paying off in the past    Credit Card
#
#    Credit_amount Savings_account_bonds Present_employment_since  \
# 0        2587000              < 10,000       1 <= ... < 4 years
# 1        5344000           ≥ 1,000,000               unemployed
# 2       14847000           ≥ 1,000,000               unemployed
# 3        3782000     100,000 – 999,999       1 <= ... < 4 years
# 4       15813000              < 10,000               >= 7 years
#
#    Installment_rate_percent_income  gender marital status  \
# 0                                3    Male         single
# 1                                2  Female       Divorced
# 2                                2  Female      Separated
# 3                                3  Female      Separated
# 4                                3    Male        Married
#
#   Other_debtors_guarantors  Present_residence_since              Property  \
# 0                     none                        2     Property Mortgage
# 1                guarantor                        4     Property Mortgage
# 2             co-applicant                        3  financial collateral
# 3                guarantor                        3  financial collateral
# 4                guarantor                        2  financial collateral
#
#    Age_in_years Other_installment_plans   Housing  \
# 0            27                    bank      rent
# 1            45                    none       own
# 2            20                    bank      rent
# 3            18                    none      rent
# 4            46                    none  for free
#
#    Number_of_existing_credits_at_this_bank          Job Category Income Level  \
# 0                                        4        Skilled worker   Low Income
# 1                                        4        Skilled worker  High Income
# 2                                        3  Salaried individuals  High Income
# 3                                        3        Skilled worker  High Income
# 4                                        4        Skilled worker  High Income
#
#    Annual Income (PKR)  Number_of_people_liable_for_maintenance Credit_Risk
# 0               763673                                        1        GOOD
# 1              8367245                                        1        GOOD
# 2              6060105                                        2        GOOD
# 3              7857096                                        2         BAD
# 4              6751079                                        1        GOOD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Client_ID                                10000 non-null  object
#  1   Status_of_existing_checking_account      10000 non-null  object
#  2   Duration_in_month                        10000 non-null  int64
#  3   Credit_history                           10000 non-null  object
#  4   Purpose                                  10000 non-null  object
#  5   Credit_amount                            10000 non-null  int64
#  6   Savings_account_bonds                    10000 non-null  object
#  7   Present_employment_since                 10000 non-null  object
#  8   Installment_rate_percent_income          10000 non-null  int64
#  9   gender                                   10000 non-null  object
#  10  marital status                           10000 non-null  object
#  11  Other_debtors_guarantors                 10000 non-null  object
#  12  Present_residence_since                  10000 non-null  int64
#  13  Property                                 10000 non-null  object
#  14  Age_in_years                             10000 non-null  int64
#  15  Other_installment_plans                  10000 non-null  object
#  16  Housing                                  10000 non-null  object
#  17  Number_of_existing_credits_at_this_bank  10000 non-null  int64
#  18  Job Category                             10000 non-null  object
#  19  Income Level                             10000 non-null  object
#  20  Annual Income (PKR)                      10000 non-null  int64
#  21  Number_of_people_liable_for_maintenance  10000 non-null  int64
#  22  Credit_Risk                              10000 non-null  object
# dtypes: int64(8), object(15)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#        Duration_in_month  Credit_amount  Installment_rate_percent_income  \
# count       10000.000000   1.000000e+04                     10000.000000
# mean           38.114300   1.017048e+07                         2.505500
# std            19.942758   5.655361e+06                         1.118524
# min             4.000000   2.500000e+05                         1.000000
# 25%            21.000000   5.322500e+06                         2.000000
# 50%            38.000000   1.021750e+07                         3.000000
# 75%            56.000000   1.501625e+07                         4.000000
# max            72.000000   2.000000e+07                         4.000000
#
#        Present_residence_since  Age_in_years  \
# count             10000.000000  10000.000000
# mean                  2.498400     46.779900
# std                   1.124599     16.682173
# min                   1.000000     18.000000
# 25%                   1.000000     32.000000
# 50%                   2.000000     47.000000
# 75%                   4.000000     61.000000
# max                   4.000000     75.000000
#
#        Number_of_existing_credits_at_this_bank  Annual Income (PKR)  \
# count                             10000.000000         1.000000e+04
# mean                                  2.506500         5.844892e+06
# std                                   1.115743         5.236164e+06
# min                                   1.000000         2.945600e+04
# 25%                                   2.000000         7.742022e+05
# 50%                                   3.000000         6.103417e+06
# 75%                                   4.000000         8.158132e+06
# max                                   4.000000         1.649816e+07
#
#        Number_of_people_liable_for_maintenance
# count                             10000.000000
# mean                                  1.495300
# std                                   0.500003
# min                                   1.000000
# 25%                                   1.000000
# 50%                                   1.000000
# 75%                                   2.000000
# max                                   2.000000

# %%
df["Credit_Risk"].value_counts()
# Out:
# Credit_Risk
# GOOD    5021
# BAD     4979
# Name: count, dtype: int64

# %%
sns.scatterplot(x="Credit_Risk", y="Installment_rate_percent_income" ,data=df)
plt.title("Duration_in_month")
# Out:
# Text(0.5, 1.0, 'Duration_in_month')
