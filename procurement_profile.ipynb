# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid", palette="pastel", font_scale=1.1)
plt.rcParams["figure.figsize"] = (10, 6)

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel("Requisition_status.xlsx")

# %%
# Drop the first 5 rows and reset index
df = df.iloc[5:].reset_index(drop=True)

# %%
# Set the first remaining row as header
df.columns = df.iloc[0]

# %%
df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 0            Requester Req No Line Num  \
# 0          AAMIR.AMEER   6081        6
# 1          AAMIR.AMEER   6081        7
# 2          ERUM.FATIMA   7123        1
# 3          ERUM.FATIMA   7123        2
# 4         HAFSA.WAHEED   7070        1
# ...                ...    ...      ...
# 27606    BASIT.HUSSAIN  12769        1
# 27607  WAJAHAT.SHAHZAD  12865        1
# 27608  WAJAHAT.SHAHZAD  12865        2
# 27609     MANJHEE.KHAN  12949        1
# 27610   MUHAMMAD.MERAJ  12952        1
#
# 0                                       Department             Req Date  \
# 0                                BRK.SD - Planning  2024-03-08 00:00:00
# 1                                BRK.SD - Planning  2024-03-08 00:00:00
# 2      BRK.S - Cephalosporin Sterile Manufacturing  2024-01-11 00:00:00
# 3      BRK.S - Cephalosporin Sterile Manufacturing  2024-01-11 00:00:00
# 4                               BRK.SD - Packaging  2024-01-02 00:00:00
# ...                                            ...                  ...
# 27606                   BRK.D - Strategic Projects  2025-10-08 00:00:00
# 27607                          BRK.D - Engineering  2025-10-15 00:00:00
# 27608                          BRK.D - Engineering  2025-10-15 00:00:00
# 27609                           BRK.SD - Packaging  2025-10-21 00:00:00
# 27610                                BRK.S - Local  2025-10-22 00:00:00
#
# 0          Submission Date   Req. Approved Date         Need By Date  \
# 0      2023-01-06 00:00:00  2023-01-06 00:00:00  2023-03-30 00:00:00
# 1      2023-01-06 00:00:00  2023-01-06 00:00:00  2023-03-30 00:00:00
# 2      2024-01-11 00:00:00  2024-01-11 00:00:00  2024-01-13 00:00:00
# 3      2024-01-11 00:00:00  2024-01-11 00:00:00  2024-01-13 00:00:00
# 4      2024-01-02 00:00:00                  NaN  2024-01-03 00:00:00
# ...                    ...                  ...                  ...
# 27606  2025-10-08 00:00:00  2025-10-15 00:00:00  2025-10-22 00:00:00
# 27607                  NaN                  NaN  2025-10-20 00:00:00
# 27608                  NaN                  NaN  2025-10-20 00:00:00
# 27609  2025-10-21 00:00:00  2025-10-21 00:00:00  2025-10-22 00:00:00
# 27610  2025-10-22 00:00:00  2025-10-23 00:00:00  2025-10-31 00:00:00
#
# 0     Req. Status Line Status       UOM Quantity  PO No     Po Approved Date  \
# 0        APPROVED    APPROVED  Kilogram      100  19788  2024-03-11 00:00:00
# 1        APPROVED    APPROVED  Kilogram      100  19790  2024-03-11 00:00:00
# 2        APPROVED    APPROVED   Numbers       12  19477  2024-01-26 00:00:00
# 3        APPROVED    APPROVED   Numbers        6  19477  2024-01-26 00:00:00
# 4        RETURNED    RETURNED   Numbers       15    NaN                  NaN
# ...           ...         ...       ...      ...    ...                  ...
# 27606    APPROVED    APPROVED  Kilogram      130  25905  2025-10-21 00:00:00
# 27607  INCOMPLETE  INCOMPLETE   Numbers        3    NaN                  NaN
# 27608  INCOMPLETE  INCOMPLETE   Numbers        4    NaN                  NaN
# 27609    APPROVED    APPROVED   Numbers       20    NaN                  NaN
# 27610    APPROVED    APPROVED   Numbers        2  26014                  NaN
#
# 0     Po Quantity Po Header Status        Po Line Status Po line Cancel  \
# 0             110         APPROVED                CLOSED            NaN
# 1             110         APPROVED                CLOSED            NaN
# 2              12         APPROVED                CLOSED            NaN
# 3               6         APPROVED                CLOSED            NaN
# 4               0              NaN                   NaN            NaN
# ...           ...              ...                   ...            ...
# 27606       107.3         APPROVED  CLOSED FOR RECEIVING            NaN
# 27607           0              NaN                   NaN            NaN
# 27608           0              NaN                   NaN            NaN
# 27609           0              NaN                   NaN            NaN
# 27610           2       INCOMPLETE                  OPEN            NaN
#
# 0     Receiving Quantity       Receiving Date        Item Code  \
# 0                    110  2024-06-06 00:00:00  1003-00186-0000
# 1                    110  2024-07-13 00:00:00  1003-00186-0000
# 2                     12  2024-08-16 00:00:00  6256-00050-0000
# 3                      6  2024-06-21 00:00:00  6256-00027-0000
# 4                      0                  NaN  6254-00156-0000
# ...                  ...                  ...              ...
# 27606              107.3  2025-10-23 00:00:00  6254-00218-0000
# 27607                  0                  NaN  5407-00121-0000
# 27608                  0                  NaN  5408-00072-0000
# 27609                  0                  NaN  5234-00078-0000
# 27610                  0                  NaN  6105-00048-0000
#
# 0                                              Item Name  \
# 0                                          CARBOMER 934P
# 1                                          CARBOMER 934P
# 2      CARTRIDGE FILTER MINI CELLULOSE ACETATE 0.45 M...
# 3      CAPSULE FILTER HYDROPHOBIC 0.22 MICRON SIZE: 4...
# 4      INK CARTRIDGE BLACK FOR NON-POROUS SUBSTRATE -...
# ...                                                  ...
# 27606                                       PLASTIC ROLL
# 27607  VAVLE SOCKET CPVC SIZE: 3" SCHEDULE 80 (BRASS ...
# 27608                      TEE CPVC SIZE: 3" SCHEDULE 80
# 27609                                 SPRAY PAINT SILVER
# 27610                                  SELF INKING STAMP
#
# 0                           Item Category               Item Subcategory  \
# 0                     Raw Material Import             General Excepients
# 1                     Raw Material Import             General Excepients
# 2            Consumable Production Supply         Filters and Cartridges
# 3            Consumable Production Supply         Filters and Cartridges
# 4            Consumable Production Supply            General Consumables
# ...                                   ...                            ...
# 27606                  General Consumable            General Consumables
# 27607  Non-Stocked Plumb & Sanitory Items                         Socket
# 27608  Non-Stocked Plumb & Sanitory Items                            Tee
# 27609                          Mechanical  Mechanical Miscellaneous Item
# 27610       Printing, Stationary & Others         Consumables Stationery
#
# 0     Project                           Supplier  \
# 0         NaN  LUBRIZOL ADVANCED MATERIALS, INC.
# 1         NaN  LUBRIZOL ADVANCED MATERIALS, INC.
# 2         NaN               MICRO SCIENTIFIC CO.
# 3         NaN               MICRO SCIENTIFIC CO.
# 4         NaN                                NaN
# ...       ...                                ...
# 27606       1      MUHAMMAD RAZA -CASH PURCHASES
# 27607     NaN                                NaN
# 27608     NaN                                NaN
# 27609     NaN                                NaN
# 27610     NaN      MUHAMMAD RAZA -CASH PURCHASES
#
# 0                                 Buyer     Note To Buyer  \
# 0                                Mumtaz               NaN
# 1                                Mumtaz               NaN
# 2                            Atif Salam               NaN
# 3                            Atif Salam               NaN
# 4                                   NaN               NaN
# ...                                 ...               ...
# 27606                               NaN               NaN
# 27607                               NaN               NaN
# 27608                               NaN               NaN
# 27609  Syed Muhammad Shoaib Abbas Zaidi               NaN
# 27610                    Muhammad Meraj  MODEL NO. S829 D
#
# 0                                                Remarks
# 0                                            Imported RM
# 1                                            Imported RM
# 2                        filter for secondary filtration
# 3                        filter for secondary filtration
# 4             solujet ink cartridges for online printers
# ...                                                  ...
# 27606  Urgently Required Plastic Covering to Protect ...
# 27607                                WASTE WATER FITTING
# 27608                                WASTE WATER FITTING
# 27609                   Silver Spray Paints are required
# 27610                Required for Procurement Department
#
# [27611 rows x 29 columns]
