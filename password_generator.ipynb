# %%
import random as r

# %%
num = r.randint(0, 9)
num
# Out:
# 7

# %%
rand_num = f"{r.randint(0, 9)}{r.randint(0, 9)}{r.randint(0, 9)}{r.randint(0, 9)}{r.randint(0, 9)}{r.randint(0, 9)}"
rand_num
# Out:
# '066827'

# %%
alph = r.randbytes(num)
alph
# Out:
# b'e\t%\xd6\x06\xadT'

# %%
s = {"a" : ["Google", "Apple", "Android"], "b": ["Orange", "Banana", "Pineapple"]}

# %%
s
# Out:
# {'a': ['Google', 'Apple', 'Android'], 'b': ['Orange', 'Banana', 'Pineapple']}

# %%
choice_1 = r.choices(["Google", "Apple", "Android"])

# %%
type(choice_1)
# Out:
# list

# %%
choice_2 = r.choice(["Google", "Apple", "Android"])

# %%
type(choice_2)
# Out:
# str
