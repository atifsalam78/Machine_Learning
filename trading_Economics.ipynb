# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
import tradingeconomics as te

# %%
# te.login('key:71827363b083479:gngqs71p9iucyvq')
# te.subscribe('calendar')

# def on_message(ws, message):
#     data = json.loads(message)
#     print(data)

# te.run(on_message)
# Out:
# You are subscribed to:['calendar']
# Handshake status 401 Unauthorized -+-+- {'date': 'Wed, 05 Nov 2025 17:25:53 GMT', 'content-type': 'text/html', 'content-length': '12', 'connection': 'keep-alive', 'set-cookie': 'AWSALB=+hGAKohbn9b3MQOdzyb1MxPMf1PZB7xP6zlfki6ybMLzfC0Y13qeSwynayN/6EPc+ky+y+7y8BoKZuyJhux9iu4VlhyEp14brOM+2LgKveEzOp14Vl1PR/EghBPD; Expires=Wed, 12 Nov 2025 17:25:53 GMT; Path=/; AWSALBCORS=+hGAKohbn9b3MQOdzyb1MxPMf1PZB7xP6zlfki6ybMLzfC0Y13qeSwynayN/6EPc+ky+y+7y8BoKZuyJhux9iu4VlhyEp14brOM+2LgKveEzOp14Vl1PR/EghBPD; Expires=Wed, 12 Nov 2025 17:25:53 GMT; Path=/; SameSite=None; Secure'} -+-+- b'Unauthorized'
# start_socket.<locals>._on_close() takes 1 positional argument but 3 were given

# %%
te.login('71827363b083479:djacedlvjjsus3h')
# Out:
# 'Logged with 71827363b083479'

# %%
df = te.getCalendarData(output_type='df')

# %%
df.head()
# Out:
#   CalendarId                 Date Country                   Category  \
# 0     386475  2025-11-05T12:00:00  Mexico         Private Investment
# 1     386474  2025-11-05T12:00:00  Mexico         Private Investment
# 2     394425  2025-11-05T10:05:00  Sweden                   Calendar
# 3     393849  2025-11-05T10:05:00  Sweden                   Calendar
# 4     386371  2025-11-05T09:00:00  Mexico  Foreign Exchange Reserves
#
#                         Event Reference        ReferenceDate  \
# 0  Gross Fixed Investment MoM       Aug  2025-08-31T00:00:00
# 1  Gross Fixed Investment YoY       Aug  2025-08-31T00:00:00
# 2            2031 SGB Auction                           None
# 3            2036 SGB Auction                           None
# 4   Foreign Exchange Reserves       Oct  2025-10-31T00:00:00
#
#                                               Source  \
# 0  Instituto Nacional de Estadística y Geografía ...
# 1  Instituto Nacional de Estadística y Geografía ...
# 2
# 3
# ...

# %%
df.shape
# Out:
# (10, 22)

# %%
df.columns
# Out:
# Index(['CalendarId', 'Date', 'Country', 'Category', 'Event', 'Reference',
#        'ReferenceDate', 'Source', 'SourceURL', 'Actual', 'Previous',
#        'Forecast', 'TEForecast', 'URL', 'DateSpan', 'Importance', 'LastUpdate',
#        'Revised', 'Currency', 'Unit', 'Ticker', 'Symbol'],
#       dtype='object')

# %%
te.getIndicatorData(country=['mexico', 'sweden'], output_type='df')
# Out:
#     Country                 Category  \
# 0    Sweden  Youth Unemployment Rate
# 1    Sweden     Withholding Tax Rate
# 2    Mexico     Withholding Tax Rate
# 3    Sweden            Weapons Sales
# 4    Sweden   Wages in Manufacturing
# ..      ...                      ...
# 294  Sweden     Average Weekly Hours
# 295  Sweden     Average Annual Wages
# 296  Mexico     Average Annual Wages
# 297  Mexico             Auto Exports
# 298  Sweden      Asylum Applications
#
#                                             Title      LatestValueDate  \
# 0                  Sweden Youth Unemployment Rate  2025-09-30T00:00:00
# 1                     Sweden Withholding Tax Rate  2025-12-31T00:00:00
# 2                     Mexico Withholding Tax Rate  2025-12-31T00:00:00
# 3                            Sweden Weapons Sales  2024-12-31T00:00:00
# 4    Sweden Average Hourly Wages in Manufacturing  2025-08-31T00:00:00
# ..                                            ...                  ...
# ...

# %%
te.getMarketsData(marketsField = 'commodities',output_type="df")
# Out:
#   Symbol Ticker Name                                            Country  Date  \
# 0                     Free accounts have access to the following cou...  None
#
#   State  Last Close CloseDate Group  ... yesterday lastWeek lastMonth  \
# 0  None  None  None      None        ...      None     None      None
#
#   lastYear startYear decimals unit frequency StartDate LastUpdate
# 0     None      None     None           None      None       None
#
# [1 rows x 34 columns]

# %%
te.getMarketsBySymbol(symbols='aapl:us', output_type="df")
# Out:
#   Symbol Ticker Name                                            Country  Date  \
# 0                     Free accounts have access to the following cou...  None
#
#   Type decimals state  Last Close  ... day_low yesterday lastWeek lastMonth  \
# 0          None  None  None  None  ...    None      None     None      None
#
#   lastYear startYear ISIN  unit frequency LastUpdate
# 0     None      None       None      None       None
#
# [1 rows x 35 columns]

# %%
te.getFinancialsData(symbol = 'aapl:us', output_type = 'df')
# Out:
#                                          Symbol                 Date  \
# 0                         aapl:us:trade-debtors  2025-09-30T00:00:00
# 1                       aapl:us:trade-creditors  2025-09-30T00:00:00
# 2                                 aapl:us:stock  2025-09-30T00:00:00
# 3   aapl:us:selling-and-administration-expenses  2025-09-30T00:00:00
# 4                                 aapl:us:sales  2025-09-30T00:00:00
# 5                        aapl:us:pre-tax-profit  2025-06-30T00:00:00
# 6                                    aapl:us:pe  2025-09-30T00:00:00
# 7                    aapl:us:outstanding-shares  2025-01-03T00:38:00
# 8                aapl:us:ordinary-share-capital  2025-09-30T00:00:00
# 9                      aapl:us:operating-profit  2025-09-30T00:00:00
# 10                   aapl:us:operating-expenses  2025-09-30T00:00:00
# 11                           aapl:us:net-income  2025-09-30T00:00:00
# 12                aapl:us:market-capitalization  2025-11-05T15:04:00
# ...

# %%
import requests

res = requests.get("https://easydata.sbp.org.pk/api/v1/dataset/TS_GP_RL_BCSIND_M/meta?api_key=3C3985AF94E95F420C8478929A7F137D2F7F4C24" ,verify = False)
# print(res.text)

# Output : '{"columns": ["Dataset Name", "Series Key", "Series Name", "Observation Date", "Observation Value", "Unit", "Observation Status", "Status Comments"], "rows": [["Country-wise Workers\' Remittances", "TS_GP_BOP_WR_M.WR0010", "Total Cash inflow of Workers\' remittances in Pakistan in a month", "2022-07-31", "2523.753816", "Million USD", "Normal", ""]]}'
# Out:
# C:\Users\atifs\anaconda3\envs\trade_env\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'easydata.sbp.org.pk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import pandas as pd
data = res.json()

# %%
# import json
# print(json.dumps(data, indent=2))

# %%
from pandas import DataFrame
from itertools import zip_longest

# Pad the lists to equal length
keys = list(data.keys())
values = zip_longest(*data.values(), fillvalue=None)

# Reconstruct rows and build DataFrame
df = DataFrame(values, columns=keys)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   columns  10 non-null     object
#  1   rows     107 non-null    object
# dtypes: object(2)
# memory usage: 1.8+ KB

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Business_Confidence_Survey_Indices.csv")

# %%
df.head()
# Out:
#                            Dataset Name Observation Date  \
# 0  Business Confidence Survey – Indices      01-Oct-2025
# 1  Business Confidence Survey – Indices      01-Oct-2025
# 2  Business Confidence Survey – Indices      01-Oct-2025
# 3  Business Confidence Survey – Indices      01-Oct-2025
# 4  Business Confidence Survey – Indices      01-Oct-2025
#
#                   Series Key  \
# 0      TS_GP_RL_BCSIND_M.BCI
# 1    TS_GP_RL_BCSIND_M.BCI_I
# 2   TS_GP_RL_BCSIND_M.BCI_IM
# 3  TS_GP_RL_BCSIND_M.BCI_IM1
# 4  TS_GP_RL_BCSIND_M.BCI_IM2
#
#                                  Series Display Name  Observation Value  \
# 0                . Business Confidence Index Overall           55.10470
# 1       ....... Business Confidence Index - Industry           54.58190
# 2           ............. BCI - Manufacturing Sector           54.69743
# 3  ................... General Economic Condition...           49.34211
# 4  ................... General Economic Condition...           54.51128
#
# ...

# %%
df.shape
# Out:
# (6955, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6955 entries, 0 to 6954
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Dataset Name                6955 non-null   object
#  1   Observation Date            6955 non-null   object
#  2   Series Key                  6955 non-null   object
#  3   Series Display Name         6955 non-null   object
#  4   Observation Value           6955 non-null   float64
#  5   Unit                        6955 non-null   object
#  6   Observation Status          6955 non-null   object
#  7   Observation Status Comment  0 non-null      float64
#  8   Sequence No.                6955 non-null   int64
#  9   Series name                 6955 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 543.5+ KB

# %%
df.drop(columns=["Dataset Name","Series Key", "Series Display Name", "Observation Status Comment"], inplace=True)

# %%
df.head()
# Out:
#   Observation Date  Observation Value             Unit Observation Status  \
# 0      01-Oct-2025           55.10470  Diffusion Index             Normal
# 1      01-Oct-2025           54.58190  Diffusion Index             Normal
# 2      01-Oct-2025           54.69743  Diffusion Index             Normal
# 3      01-Oct-2025           49.34211  Diffusion Index             Normal
# 4      01-Oct-2025           54.51128  Diffusion Index             Normal
#
#    Sequence No.                                        Series name
# 0            10                  Business Confidence Index Overall
# 1            20               Business Confidence Index - Industry
# 2            30                                BCI - Manufacturing
# 3            40  BCI - Manufacturing-General Economic Condition...
# 4            50  BCI - Manufacturing-General Economic Condition...

# %%
df.shape
# Out:
# (6955, 6)

# %% [markdown]
# # Data Commons Python API V2

# %%
import datacommons_client

# %%
from datacommons_client.client import DataCommonsClient
# client = DataCommonsClient(api_key="AIzaSyCTI4Xz-UW_G2Q2RfknhcfdAnTHq5X5XuI")

# %%
client = DataCommonsClient(dc_instance="datacommons.one.org")

# %%
response = client.resolve.fetch_dcids_by_name(names="Georgia")
print(response)
# ResolveResponse(entities=[Entity(node='Georgia', candidates=[Candidate(dcid='geoId/13', dominantType=None), Candidate(dcid='country/GEO', dominantType=None), Candidate(dcid='geoId/5027700', dominantType=None)])])
# Out:
# {
#   "entities": [
#     {
#       "node": "Georgia",
#       "candidates": [
#         {
#           "dcid": "geoId/13"
#         },
#         {
#           "dcid": "country/GEO"
#         },
#         {
#           "dcid": "geoId/5027700"
#         }
#       ]
#     }
#   ]
# }
